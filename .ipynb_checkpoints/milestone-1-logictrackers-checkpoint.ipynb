# %%
import pandas as pd
from web3 import Web3
import json
import time

# Load IoT dataset generated from Homework 1
df = pd.read_csv("iot_data.csv")
df.head()
# Out:
#              timestamp package_id  order_date delivery_date  \
# 0  2025-05-24 21:55:38     PKG001  2025-05-22    2025-06-01
# 1  2025-05-25 18:12:38     PKG002  2025-05-20    2025-05-27
# 2  2025-05-24 21:59:38     PKG003  2025-05-19    2025-05-28
# 3  2025-05-25 17:42:38     PKG004  2025-05-22    2025-06-01
# 4  2025-05-25 18:32:38     PKG005  2025-05-21    2025-05-30
#
#                            origin     origin_coordinates  \
# 0        Puerto Princesa, Palawan   9.7808779,118.730191
# 1  General Santos, South Cotabato  6.1122217,125.1721893
# 2        Tacurong, Sultan Kudarat  6.6884368,124.6786576
# 3   San Carlos, Negros Occidental  10.486048,123.4190385
# 4      Ozamiz, Misamis Occidental  8.1470175,123.8459793
#
#                   current_location     current_coordinates  \
# 0                       Tubo, Abra     9.777611,118.740863
# 1  Pagalungan, Maguindanao del Sur     6.113452,125.166222
# 2                 Tubungan, Iloilo   10.7653357,122.318261
# 3           Nampicuan, Nueva Ecija  15.7321724,120.6386089
# 4                 Malvar, Batangas     8.140163,123.865499
#
#                  delivery_location    delivery_coordinates perishable  \
# 0                       Tubo, Abra  17.2582154,120.7248438         No
# 1  Pagalungan, Maguindanao del Sur   7.0599392,124.6992377        Yes
# 2                 Tubungan, Iloilo   10.7653357,122.318261        Yes
# 3           Nampicuan, Nueva Ecija  15.7321724,120.6386089         No
# 4                 Malvar, Batangas   14.0472848,121.157631        Yes
#
#    temperature_celsius temperature_issue      status
# 0                21.20               NaN  In Transit
# 1                11.84   Temp Alert >7°C  In Transit
# 2                10.41   Temp Alert >7°C   Delivered
# 3                20.66               NaN   Delivered
# 4                 5.41            Normal  In Transit

# %%
# Connect to local Ganache blockchain
ganache_url = "http://127.0.0.1:7545"
web3 = Web3(Web3.HTTPProvider(ganache_url))

if web3.is_connected():
    print("Connected to Ganache successfully.")
else:
    raise ConnectionError("Connection failed. Ensure Ganache is running.")
# Out:
# Connected to Ganache successfully.

# %%
# Load the ABI and contract address from Remix
with open("abi.json", "r") as abi_file:
    abi = json.load(abi_file)

contract_address = web3.to_checksum_address("0x14208d20d96abB5b79136dF68683550b1CE64CB8")
contract = web3.eth.contract(address=contract_address, abi=abi)

# %%
# Set default sender (typically the first account from Ganache)
web3.eth.default_account = web3.eth.accounts[0]
print(f"Connected to Smart Contract at {contract_address}")
# Out:
# Connected to Smart Contract at 0x14208d20d96abB5b79136dF68683550b1CE64CB8

# %%
# Define a function to send each row of IoT data to the blockchain
def send_iot_data(row):
    txn = contract.functions.storeData(
        str(row["package_id"]),
        str(row["order_date"]),
        str(row["delivery_date"]),
        str(row["origin"]),
        str(row["current_location"]),
        str(row["delivery_location"]),
        str(row["perishable"]),
        str(row["temperature_celsius"]),
        str(row["temperature_issue"]),
        str(row["status"])
    ).transact({
        'from': web3.eth.default_account,
        'gas': 3000000
    })
    receipt = web3.eth.wait_for_transaction_receipt(txn)
    print(f"Stored {row['package_id']} | Status: {row['status']} | Txn Hash: {receipt.transactionHash.hex()}")

# %%
# Loop through the DataFrame and send each row to the blockchain
for _, row in df.iterrows():
    send_iot_data(row)
    time.sleep(1)  # Avoid flooding the blockchain with transactions
# Out:
# Stored PKG001 | Status: In Transit | Txn Hash: 95f66e8c7957b8d6239362a5d3cd904bb82f4424b4d516ea3dfffc6715cadfef
# Stored PKG002 | Status: In Transit | Txn Hash: 513bcdb7820da2367c9345c2a094ae6716becb2fc973a429d06d0223a6e9ec21
# Stored PKG003 | Status: Delivered | Txn Hash: 38065fa452b6879f32c5f7f1f961028e7042f88051e06da2b9a22770370d4f4b
# Stored PKG004 | Status: Delivered | Txn Hash: 156c47afa08def083a48a00e1215922f7c1c359e0174d34ec6b9e5d9472c17a2
# Stored PKG005 | Status: In Transit | Txn Hash: 8eae565accf7028ac7caf3a814f8049bccfd9b4bef417bc6534cc349adedf2d3
# Stored PKG006 | Status: Delayed | Txn Hash: d5b7b743c8428fc53adbbd5fe0a04e9e2943d04c0c7af8087a8f9454c65aedf2
# Stored PKG007 | Status: Awaiting Pickup | Txn Hash: a98f3dfc78c84f4c1395f7e53b0274a9392f42c61e962b7a7e6330b40b4d3bea
# Stored PKG008 | Status: In Transit | Txn Hash: ca6bc0a7fd1e54ef38ce44ef267ea21748bc1f237027192ed4c204909fe7f238
# Stored PKG009 | Status: Delivered | Txn Hash: fb7c90b3202409d0c1ba1745d3c9240b020690d039962f78e346f93355d419d1
# Stored PKG010 | Status: Awaiting Pickup | Txn Hash: 6e6ef9030f74e61b93e296f80991771f1dd8b86d466e737083b4c26010b53341
# Stored PKG011 | Status: In Transit | Txn Hash: ee1619fcf7a611c7f44787d2cb61d46a2fb22cfd6ade42d225e94f6d245f05aa
# Stored PKG012 | Status: Delivered | Txn Hash: 3afb9d79296ece9f77642a6496ed957128715da701b6581505bc69ff729251aa
# Stored PKG013 | Status: Awaiting Pickup | Txn Hash: f5acc00702f15f4c795745e76a46aad266f4a309cc9d5cb66557f5742bfaf95a
# Stored PKG014 | Status: Delivered | Txn Hash: be77f5e886f23eea7520011ac77c64ce7dd01cc57fc337fe98067fbb2953f1a1
# Stored PKG015 | Status: Awaiting Pickup | Txn Hash: b62a5796971041827ce9df2c7443ba49eb0873b8ce4ea4ca84a86b75e57c58d9
# Stored PKG016 | Status: Delivered | Txn Hash: d2a8633a320c47edc2b372867cbf3b6a524288e09909671ab5764a1984e2dbe9
# Stored PKG017 | Status: Awaiting Pickup | Txn Hash: c2c1a132f77f35263bb681a325b30b0d23faa86591f605bcad74cba39c04ac72
# Stored PKG018 | Status: Awaiting Pickup | Txn Hash: 5098afc4dfb2fafcdd4b0693dda55597c04d94f82157a66ac768b49fc321f0c5
# Stored PKG019 | Status: Delivered | Txn Hash: 5e7b8063b49832b34deb62a23cb4036fd2d2cc507ecc1ab9275f4f6f21da7d61
# Stored PKG020 | Status: In Transit | Txn Hash: 74eeef5e7ae410ed7c0734e87b756d9ea962c5cb7d8b21bac901f3da117bde0f
# Stored PKG021 | Status: Awaiting Pickup | Txn Hash: e51cc3e1be4a126d8e8020664401dc53a66f7554e5e8e6fec9a5404ba6fefbb1
# Stored PKG022 | Status: Delivered | Txn Hash: 23dbb53eea148ae87b4483e551b14f3069a7735a81b4d85ea2257b2d8e19390c
# Stored PKG023 | Status: In Transit | Txn Hash: 7b2f030eb5d5ead559b52cf478b63abf2850b0fa801d62bf6c50ab64d0101557
# Stored PKG024 | Status: Delivered | Txn Hash: b6a6eb5110c234330a1707333a0519c423efb54e62585be97999da482c766792
# Stored PKG025 | Status: Awaiting Pickup | Txn Hash: 25be7049180e9843f7c4604c7a9b39122a96acff1f4e5fdb7aeaade17f7df807
# Stored PKG026 | Status: In Transit | Txn Hash: ae5026929be26b7128237028b8f6d5d67fb0dc08489b3bd49fe0dff1ce5d8a5e
# Stored PKG027 | Status: Delivered | Txn Hash: e1f526903fbc649cf231b06cefed3b73d21f34ff4b43cc957e6956e8b9c83e8d
# Stored PKG028 | Status: In Transit | Txn Hash: a393d61b3d85b3c68898dc162342df47f84b3e48b88b4fc7be4dc225f7f61784
# Stored PKG029 | Status: Awaiting Pickup | Txn Hash: dafd75a5791535b82cd07e8fd547f8f485c8294313584a72686143f243955463
# Stored PKG030 | Status: Awaiting Pickup | Txn Hash: 642d03d812fc4363fceca3b1f00d96ef2109cd68690bbb3f01cd4f69a853c004
# Stored PKG031 | Status: In Transit | Txn Hash: 16edfaef220c9459c229a2cb07e07b7492c32b45be758370f40a2209e1655f84
# Stored PKG032 | Status: In Transit | Txn Hash: 6670c54fbbc66d740755bc1ad7740fa4f8a278bbb15caf9264f0cd627fb68678
# Stored PKG033 | Status: Awaiting Pickup | Txn Hash: 4b72d7ed0fb4ff879d3214d0a65ee2445417d462335e2bcd49b7cd4b1dca7d86
# Stored PKG034 | Status: Awaiting Pickup | Txn Hash: bc8bd2864851eb5dd9d4dd8ba5a0103e815d33ad421d9bc178d83849a1ed50e6
# Stored PKG035 | Status: In Transit | Txn Hash: e4e53c006cbdafb76cd0b26dfc0a4ac7792dfaaeb7d3ba5653f83d7aba1de685
# Stored PKG036 | Status: Delivered | Txn Hash: 755f33b95fb361e0dd43ae9a7b9d9c16bfc322e3e7e16ff95ef4d3cf88e18935
# Stored PKG037 | Status: Awaiting Pickup | Txn Hash: ff5bc0a579e649597f4d9e675795136a195dcd1ae7376b001a9ac3a7e0c9cd74
# Stored PKG038 | Status: In Transit | Txn Hash: b9961561f9a50b416295315a91f4ae235bb69d68afe320ba1fb811d2647ac314
# Stored PKG039 | Status: Awaiting Pickup | Txn Hash: f720b14211f41bb729e81c47c78183992586833a7bece1b499ccf856fb3ac441
# Stored PKG040 | Status: Awaiting Pickup | Txn Hash: 57d0eb97160f9b5f8bf37337d746a98b2f0845c9f8e661efd4c75944aaa2f147
# Stored PKG041 | Status: Awaiting Pickup | Txn Hash: a605834b248919aad2ecc4bae3660d6e1a8733fa588c895f85bfbbb96ecf0181
# Stored PKG042 | Status: Awaiting Pickup | Txn Hash: 0b4bb771126ee1f1a405b4d903918b9835ecb67d25ac18b835fd2ec49873458a
# Stored PKG043 | Status: Awaiting Pickup | Txn Hash: 9c5e4ed16fb008b73e3f1fbce0c25430e7a2a9effbc16790ea5c72aeaecf9076
# Stored PKG044 | Status: Awaiting Pickup | Txn Hash: 3f48296c2c6d62db71529e15338b19d19315d254e114be0ddff4171c037180ce
# Stored PKG045 | Status: Awaiting Pickup | Txn Hash: 65214f927fc8ce28bcfe98ddb4cc069b383cff588b9de9206fa6da78cd75be69
# Stored PKG046 | Status: Awaiting Pickup | Txn Hash: 3d6a4073932fa03d7f3e610c366e3ce62e0c970f40d93b0da59469565a95eb88
# Stored PKG047 | Status: Awaiting Pickup | Txn Hash: c3373b032e42dcffcc91e55330c674d991837e0dbfb269242d4e199b6f3066d2
# Stored PKG048 | Status: Awaiting Pickup | Txn Hash: c3ffa09ed5b77591b9e0c66abf235a2ffe1971e2b8d29d4bb888ed4fd6ceb746
# Stored PKG049 | Status: Delivered | Txn Hash: 1f0928dcafa64c43b863ae29bb5d3aceb24f188a56441b7e3f67426303f21e38
# Stored PKG050 | Status: Awaiting Pickup | Txn Hash: d4b286d6553e1b5cad71b55615966001d1ac5ff955e3a1971b3c3591fe036541
# Stored PKG051 | Status: Awaiting Pickup | Txn Hash: eee8fe5823c4b85c93df642478878553ec3ab2c9ccf7a0c1a16320b43ca8d8e1
# Stored PKG052 | Status: In Transit | Txn Hash: 85c03760b59a4242a90509621227330d94244b13e8f0f7fe8c811bbb0dfcdd99
# Stored PKG053 | Status: In Transit | Txn Hash: 468880237adcc5bce6897a6ff3619480845d2b360c78ce561465d904f8ae36b3
# Stored PKG054 | Status: Awaiting Pickup | Txn Hash: e27ac1dc531a87aabf336f600cd42eb621b085179ce9d770caa28e5b617aa704
# Stored PKG055 | Status: Delivered | Txn Hash: dcedfee7c3908f4277f4de6429cb73c7abb4b076b849f7425dcefdd874d46376
# Stored PKG056 | Status: Awaiting Pickup | Txn Hash: a244dfc1cbce94e80fcfd5dcc3c5dc8a4957fa483d32b0ccfffc37811e527202
# Stored PKG057 | Status: In Transit | Txn Hash: 5b78cee8716a5d9067b1cc998a89aa30e08bc65ae49fadbc346451afc8ed0410
# Stored PKG058 | Status: Awaiting Pickup | Txn Hash: b9eab5b670779de5b58b4b96b34fdbc8f18edeebbf2703fd20bb98b403346656
# Stored PKG059 | Status: Awaiting Pickup | Txn Hash: 4b92e6686441c0684878ced2d3c5d177ed331975ec9178f3a029a798c2ea2432
# Stored PKG060 | Status: In Transit | Txn Hash: 8f8829bc91fabbe1260940654cbff57a9a61bff4f09c83a87d47dc66d170ca8c
# Stored PKG061 | Status: Awaiting Pickup | Txn Hash: 459be9ea3d24bf8e006f30f2eea5e8cf69950872854f411b2db24f86fb023c63
# Stored PKG062 | Status: Delivered | Txn Hash: fb2a010f5a0914e09c2841afc0bc04348dc59db285f96504d361a6ada0cc0467
# Stored PKG063 | Status: Delivered | Txn Hash: efb08ba1babbb3fd329b5e9309e773fca4238141367556dd21b4097faadab0f3
# Stored PKG064 | Status: Awaiting Pickup | Txn Hash: 03ad61fc46f12b1d37a100112ef29e536bb1c62c40e3ac37843869c2d08db4f6
# Stored PKG065 | Status: In Transit | Txn Hash: 506a767599ff393ffe82996c58582ca8d32319f6f341b9da424961a4ca94fb31
# Stored PKG066 | Status: Delayed | Txn Hash: 47aed2b2db1aa4c2db5ae728805ce0a274b3654dfcf926aa3153efe0120520be
# Stored PKG067 | Status: Awaiting Pickup | Txn Hash: d5b1c11c829e5058c2449ad497643b9e4256d479f87b7ab945dbc2f8808233ee
# Stored PKG068 | Status: Delivered | Txn Hash: 210756de5ebe466e6a7f2028f98a18574b62116ab258bebd5da89bf275693092
# Stored PKG069 | Status: In Transit | Txn Hash: 8528e297c195df659b7757a2b4e6b6211b4bc94003a649ff15f0c7868ecac938
# Stored PKG070 | Status: Awaiting Pickup | Txn Hash: c30343a0a7b4c92a9cd3fb7b2e84f3039d381277ec037f7c829ce8e87530b5e4
# Stored PKG071 | Status: In Transit | Txn Hash: 30b6f40447199c46ddedf066512dc5c37c30309c5506ac9ca2abca2de777b86e
# Stored PKG072 | Status: Awaiting Pickup | Txn Hash: c6a7dfb400cfa174ed40e94720da5adfe952e877aec5115dfd00befba822e6eb
# Stored PKG073 | Status: Awaiting Pickup | Txn Hash: 5064f18b5e84e1c288f747152be586d347114caad741d34c42c7d004ab8f07fe
# Stored PKG074 | Status: Awaiting Pickup | Txn Hash: b6289b1d37821084eb60a9cdeb351deb9b621168016763c34a8c5c42f051e422
# Stored PKG075 | Status: Delivered | Txn Hash: 26880a211cf69867d295ae7e87cac06e78c7e3d3ec3d675a17085d85095aa4b9
# Stored PKG076 | Status: Delayed | Txn Hash: f3fb2455c58f37252a99476cd243347b93396e2618f3effe73722ef5f0d79ac9
# Stored PKG077 | Status: Delivered | Txn Hash: 06df74c09b1dec374036cc70fc0da0287ab2d522f3401ae774cefb5671971991
# Stored PKG078 | Status: In Transit | Txn Hash: b86c73f55fc0d6ca2a994a0ec3ce8107fb1698ff7d628661dfc8ef791bdfebda
# Stored PKG079 | Status: In Transit | Txn Hash: 7e0dedb386214855c919674f2285eb6e10081f555ae71785a34a750e93c20318
# Stored PKG080 | Status: Delivered | Txn Hash: f526e7852c3b97d9cb068d17c55c00e1bc82d6d289160e18030ac0fcc5c4ade0
# Stored PKG081 | Status: In Transit | Txn Hash: a1f43d90d5665a962cd96c3cbc0dd0e1f4b8c6d6ba2bad6fd18effd2d2201e8b
# Stored PKG082 | Status: Awaiting Pickup | Txn Hash: f6628ed9333f04fb9612f99ad9803d11e9b2d25a37551c268bdcc35e4bb45124
# Stored PKG083 | Status: In Transit | Txn Hash: 60dfd96a30971005e1c8246441ba6ec143f647b46e2f50c9f628ac0bac350ea2
# Stored PKG084 | Status: Awaiting Pickup | Txn Hash: f9d3e837cdc8577f10a8453652ba8cb85a3a6dff1d737613eea6b35245608b3c
# Stored PKG085 | Status: Awaiting Pickup | Txn Hash: 6932a33b10c85bf9e5acbc921a5fdc632790f4db27d0821489770df257465823
# Stored PKG086 | Status: Delivered | Txn Hash: ddc851135175688c3ffffc3a26c0c98bee7432a2a1e93daed8ff90c7ee2b6789
# Stored PKG087 | Status: Awaiting Pickup | Txn Hash: 8aa6adc190aa92a613c4aa6eda847ae6c2ff87d507b1709ff889f4b7d23c4616
# Stored PKG088 | Status: In Transit | Txn Hash: 550221f80c641062a5af35af770a0fc013f28eff5c80d41404aa2dbf9a1b3496
# Stored PKG089 | Status: In Transit | Txn Hash: 211ee86696f42ae308ff8e77049327be8fc6e2a109a2fe2e430b8a9d38326fa3
# Stored PKG090 | Status: Awaiting Pickup | Txn Hash: 2d9e29811a4dd8d5f7e90fa961a49b22e900d3bd564e65bf7e40956e39612d30
# Stored PKG091 | Status: In Transit | Txn Hash: 91e79f181da2e9b2567afc2a442ad3e7171cc0742a0bd4ea92446f098e07a0e8
# Stored PKG092 | Status: In Transit | Txn Hash: 5e69505304616dba7751f0dd0a98c3720f8cc42505a77ae5c13894901b7e8f05
# Stored PKG093 | Status: In Transit | Txn Hash: b321ba11af8eb5f3ecdcc9e63bc71dcfeea0be0b1a3ba9cdbe1a025c6ff73abb
# Stored PKG094 | Status: Delayed | Txn Hash: c5c43867f3e7be22028f4cbb911fb29b6f212a5130d4c69b04618d9315f32f6a
# Stored PKG095 | Status: Delivered | Txn Hash: 5b5413d677fc3a54dd09f52848e8c9e65f4e669573114565d1f4b3f79f97d5a0
# Stored PKG096 | Status: In Transit | Txn Hash: f3ef851e95ef242cf4733bebf4cd320ef4b005266b7ade895020cb9386ed68be
# Stored PKG097 | Status: Awaiting Pickup | Txn Hash: 335451821a2b566fb027f70bd3be0973957be7d514bd505bd79a9217926a9ac5
# Stored PKG098 | Status: Awaiting Pickup | Txn Hash: a179791ac154ad42f1365661bcf6d3877c67e9ef44df1d5b4983259d851468c8
# Stored PKG099 | Status: Delivered | Txn Hash: c3c796ba84e764fe8b5bc0b6fa4482e13f17f218de81e67860b1de1a5f235dea
# Stored PKG100 | Status: In Transit | Txn Hash: 819b186e29727468b7962737951a5eaa36d820d6dc951a02d6b8b0ffcf507429

# %%
# Verify the total number of records stored
total_records = contract.functions.getTotalRecords().call()
print(f"Total IoT records stored: {total_records}")
# Out:
# Total IoT records stored: 100

# %%
# Retrieve and display the first stored record
first_record = contract.functions.getRecord(0).call()
print("First Stored Record:", first_record)
# Out:
# First Stored Record: [1748174030, 'PKG001', '2025-05-22', '2025-06-01', 'Puerto Princesa, Palawan', 'Tubo, Abra', 'Tubo, Abra', 'No', '21.2', 'nan', 'In Transit']
